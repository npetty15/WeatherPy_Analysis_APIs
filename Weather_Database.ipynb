# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities: 
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
# Import the requests library.
import requests

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nenjiang
# Processing Record 2 of Set 1 | zyryanka
# Processing Record 3 of Set 1 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | omsukchan
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | arrecife
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | caraquet
# Processing Record 12 of Set 1 | akdepe
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | reforma
# Processing Record 18 of Set 1 | carnarvon
# Processing Record 19 of Set 1 | broome
# Processing Record 20 of Set 1 | nemuro
# Processing Record 21 of Set 1 | bumba
# Processing Record 22 of Set 1 | talnakh
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | cabo san lucas
# Processing Record 26 of Set 1 | bonthe
# Processing Record 27 of Set 1 | bambanglipuro
# Processing Record 28 of Set 1 | dingle
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | san cristobal
# Processing Record 35 of Set 1 | ust-nera
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | tilichiki
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | kapit
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | la asuncion
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | bystryy istok
# Processing Record 46 of Set 1 | safaga
# Processing Record 47 of Set 1 | kologriv
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | sibolga
# Processing Record 2 of Set 2 | santa maria
# Processing Record 3 of Set 2 | rawson
# Processing Record 4 of Set 2 | monrovia
# Processing Record 5 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 6 of Set 2 | takoradi
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | sur
# Processing Record 9 of Set 2 | nanortalik
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | fairbanks
# Processing Record 15 of Set 2 | muros
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | port lincoln
# Processing Record 18 of Set 2 | chokurdakh
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | panguna
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | phalaborwa
# Processing Record 23 of Set 2 | zeya
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | lavrentiya
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | ksenyevka
# City not found. Skipping...
# Processing Record 29 of Set 2 | barranca
# Processing Record 30 of Set 2 | lisala
# Processing Record 31 of Set 2 | poum
# Processing Record 32 of Set 2 | pekan
# Processing Record 33 of Set 2 | mataura
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | morropon
# Processing Record 36 of Set 2 | faya
# Processing Record 37 of Set 2 | tzaneen
# Processing Record 38 of Set 2 | teahupoo
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | vila velha
# Processing Record 41 of Set 2 | san fernando
# Processing Record 42 of Set 2 | san lorenzo
# Processing Record 43 of Set 2 | mineiros
# Processing Record 44 of Set 2 | namatanai
# Processing Record 45 of Set 2 | lorengau
# Processing Record 46 of Set 2 | realeza
# Processing Record 47 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 2 | quatre cocos
# Processing Record 49 of Set 2 | itarema
# Processing Record 50 of Set 2 | orkney
# Processing Record 1 of Set 3 | odweyne
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | allanmyo
# City not found. Skipping...
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | svetlogorsk
# Processing Record 7 of Set 3 | zhanaozen
# Processing Record 8 of Set 3 | ulladulla
# Processing Record 9 of Set 3 | san jeronimo
# Processing Record 10 of Set 3 | bandarbeyla
# Processing Record 11 of Set 3 | lokosovo
# Processing Record 12 of Set 3 | souillac
# Processing Record 13 of Set 3 | burica
# City not found. Skipping...
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | havelock
# Processing Record 16 of Set 3 | suntar
# Processing Record 17 of Set 3 | manta
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 3 | abadan
# Processing Record 21 of Set 3 | mezdra
# Processing Record 22 of Set 3 | baykit
# Processing Record 23 of Set 3 | manokwari
# Processing Record 24 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 3 | samarinda
# Processing Record 26 of Set 3 | aljubarrota
# Processing Record 27 of Set 3 | orcopampa
# Processing Record 28 of Set 3 | novo aripuana
# Processing Record 29 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 3 | tautira
# Processing Record 31 of Set 3 | ancud
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | clyde river
# Processing Record 34 of Set 3 | chuy
# Processing Record 35 of Set 3 | mehamn
# Processing Record 36 of Set 3 | ovsyanka
# Processing Record 37 of Set 3 | labrea
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | brejo
# Processing Record 40 of Set 3 | bage
# Processing Record 41 of Set 3 | east london
# Processing Record 42 of Set 3 | nelson bay
# Processing Record 43 of Set 3 | geraldton
# Processing Record 44 of Set 3 | beloha
# Processing Record 45 of Set 3 | thunder bay
# Processing Record 46 of Set 3 | gorontalo
# Processing Record 47 of Set 3 | were ilu
# Processing Record 48 of Set 3 | camacha
# Processing Record 49 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 3 | maniitsoq
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | kieta
# Processing Record 3 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 4 | tuatapere
# Processing Record 5 of Set 4 | mataram
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | disna
# Processing Record 8 of Set 4 | ilulissat
# Processing Record 9 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 4 | sao filipe
# Processing Record 12 of Set 4 | xichang
# Processing Record 13 of Set 4 | shingu
# Processing Record 14 of Set 4 | ishinomaki
# Processing Record 15 of Set 4 | bambous virieux
# Processing Record 16 of Set 4 | altamira
# Processing Record 17 of Set 4 | katangli
# Processing Record 18 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 19 of Set 4 | todos santos
# Processing Record 20 of Set 4 | genhe
# Processing Record 21 of Set 4 | ayagoz
# Processing Record 22 of Set 4 | te anau
# Processing Record 23 of Set 4 | buchanan
# Processing Record 24 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 4 | pisco
# Processing Record 26 of Set 4 | seydi
# Processing Record 27 of Set 4 | samarai
# Processing Record 28 of Set 4 | vanimo
# Processing Record 29 of Set 4 | barrow
# Processing Record 30 of Set 4 | bakchar
# Processing Record 31 of Set 4 | dudinka
# Processing Record 32 of Set 4 | ponta do sol
# Processing Record 33 of Set 4 | los llanos de aridane
# Processing Record 34 of Set 4 | pachperwa
# Processing Record 35 of Set 4 | dickinson
# Processing Record 36 of Set 4 | jacareacanga
# Processing Record 37 of Set 4 | sitka
# Processing Record 38 of Set 4 | sola
# Processing Record 39 of Set 4 | la ronge
# Processing Record 40 of Set 4 | lalibela
# Processing Record 41 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 4 | thompson
# Processing Record 43 of Set 4 | hualmay
# Processing Record 44 of Set 4 | kununurra
# Processing Record 45 of Set 4 | skiros
# City not found. Skipping...
# Processing Record 46 of Set 4 | qaqortoq
# Processing Record 47 of Set 4 | seoul
# Processing Record 48 of Set 4 | buluang
# Processing Record 49 of Set 4 | victor harbor
# Processing Record 50 of Set 4 | port macquarie
# Processing Record 1 of Set 5 | rio gallegos
# Processing Record 2 of Set 5 | blythe
# Processing Record 3 of Set 5 | waipawa
# Processing Record 4 of Set 5 | parras
# City not found. Skipping...
# Processing Record 5 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 5 | stromness
# Processing Record 7 of Set 5 | lucapa
# Processing Record 8 of Set 5 | adrar
# Processing Record 9 of Set 5 | uvalde
# Processing Record 10 of Set 5 | rafaela
# Processing Record 11 of Set 5 | gravdal
# Processing Record 12 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 5 | the valley
# Processing Record 14 of Set 5 | flinders
# Processing Record 15 of Set 5 | pangkalanbuun
# Processing Record 16 of Set 5 | kaitangata
# Processing Record 17 of Set 5 | mandalgovi
# Processing Record 18 of Set 5 | ribeira brava
# Processing Record 19 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 5 | kargasok
# Processing Record 21 of Set 5 | srednekolymsk
# Processing Record 22 of Set 5 | puerto narino
# Processing Record 23 of Set 5 | hovd
# Processing Record 24 of Set 5 | rabo de peixe
# Processing Record 25 of Set 5 | alugan
# Processing Record 26 of Set 5 | severo-kurilsk
# Processing Record 27 of Set 5 | vrangel
# Processing Record 28 of Set 5 | iqaluit
# Processing Record 29 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 5 | port augusta
# Processing Record 31 of Set 5 | altay
# Processing Record 32 of Set 5 | mangai
# Processing Record 33 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 5 | upernavik
# Processing Record 35 of Set 5 | rudsar
# Processing Record 36 of Set 5 | caravelas
# Processing Record 37 of Set 5 | nouadhibou
# Processing Record 38 of Set 5 | bethel
# Processing Record 39 of Set 5 | kahului
# Processing Record 40 of Set 5 | aden
# Processing Record 41 of Set 5 | egvekinot
# Processing Record 42 of Set 5 | hoyerswerda
# Processing Record 43 of Set 5 | benavente
# Processing Record 44 of Set 5 | aykhal
# Processing Record 45 of Set 5 | kloulklubed
# Processing Record 46 of Set 5 | tura
# Processing Record 47 of Set 5 | cramlington
# Processing Record 48 of Set 5 | libreville
# Processing Record 49 of Set 5 | birao
# Processing Record 50 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 6 | gonbad-e qabus
# Processing Record 2 of Set 6 | ambilobe
# Processing Record 3 of Set 6 | buala
# Processing Record 4 of Set 6 | yar-sale
# Processing Record 5 of Set 6 | pandan
# Processing Record 6 of Set 6 | pangai
# Processing Record 7 of Set 6 | eureka
# Processing Record 8 of Set 6 | ardakan
# Processing Record 9 of Set 6 | half moon bay
# Processing Record 10 of Set 6 | basco
# Processing Record 11 of Set 6 | bontang
# Processing Record 12 of Set 6 | katsuura
# Processing Record 13 of Set 6 | marawi
# Processing Record 14 of Set 6 | kamenka
# Processing Record 15 of Set 6 | hay river
# Processing Record 16 of Set 6 | yellowknife
# Processing Record 17 of Set 6 | richards bay
# Processing Record 18 of Set 6 | male
# Processing Record 19 of Set 6 | airai
# Processing Record 20 of Set 6 | touros
# Processing Record 21 of Set 6 | san quintin
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | faanui
# Processing Record 24 of Set 6 | lebu
# Processing Record 25 of Set 6 | mudgee
# Processing Record 26 of Set 6 | erzin
# Processing Record 27 of Set 6 | beringovskiy
# Processing Record 28 of Set 6 | saint-georges
# Processing Record 29 of Set 6 | georgetown
# Processing Record 30 of Set 6 | qurayyat
# Processing Record 31 of Set 6 | carutapera
# Processing Record 32 of Set 6 | margate
# Processing Record 33 of Set 6 | santa ines
# Processing Record 34 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 6 | isangel
# Processing Record 36 of Set 6 | shimoda
# Processing Record 37 of Set 6 | trincomalee
# Processing Record 38 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 6 | longyearbyen
# Processing Record 40 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 6 | kawalu
# Processing Record 42 of Set 6 | rosarito
# Processing Record 43 of Set 6 | sorland
# Processing Record 44 of Set 6 | yakhroma
# Processing Record 45 of Set 6 | prince george
# Processing Record 46 of Set 6 | acapulco
# Processing Record 47 of Set 6 | kiruna
# Processing Record 48 of Set 6 | torbay
# Processing Record 49 of Set 6 | miandrivazo
# Processing Record 50 of Set 6 | charters towers
# Processing Record 1 of Set 7 | lagoa
# Processing Record 2 of Set 7 | mount isa
# Processing Record 3 of Set 7 | myaundzha
# Processing Record 4 of Set 7 | wenling
# Processing Record 5 of Set 7 | lambarene
# Processing Record 6 of Set 7 | coquimbo
# Processing Record 7 of Set 7 | langeskov
# Processing Record 8 of Set 7 | pachino
# Processing Record 9 of Set 7 | haines junction
# Processing Record 10 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 7 | grand gaube
# Processing Record 12 of Set 7 | changping
# Processing Record 13 of Set 7 | hasaki
# Processing Record 14 of Set 7 | amapa
# Processing Record 15 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 7 | ulaangom
# Processing Record 17 of Set 7 | neresnytsya
# Processing Record 18 of Set 7 | leningradskiy
# Processing Record 19 of Set 7 | roanoke rapids
# Processing Record 20 of Set 7 | dhidhdhoo
# Processing Record 21 of Set 7 | astana
# Processing Record 22 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 23 of Set 7 | dolores
# Processing Record 24 of Set 7 | puli
# Processing Record 25 of Set 7 | falaleu
# City not found. Skipping...
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | yumen
# Processing Record 28 of Set 7 | jimenez
# Processing Record 29 of Set 7 | paita
# Processing Record 30 of Set 7 | coahuayana
# Processing Record 31 of Set 7 | honghu
# Processing Record 32 of Set 7 | sao felix do xingu
# Processing Record 33 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 7 | elat
# Processing Record 35 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 36 of Set 7 | northam
# Processing Record 37 of Set 7 | padang
# Processing Record 38 of Set 7 | yining
# Processing Record 39 of Set 7 | katobu
# Processing Record 40 of Set 7 | walvis bay
# Processing Record 41 of Set 7 | bulgan
# Processing Record 42 of Set 7 | cowra
# Processing Record 43 of Set 7 | champerico
# Processing Record 44 of Set 7 | sabha
# Processing Record 45 of Set 7 | bay roberts
# Processing Record 46 of Set 7 | harer
# Processing Record 47 of Set 7 | swan river
# Processing Record 48 of Set 7 | semey
# Processing Record 49 of Set 7 | pokrovsk
# Processing Record 50 of Set 7 | mersing
# Processing Record 1 of Set 8 | moree
# Processing Record 2 of Set 8 | garissa
# Processing Record 3 of Set 8 | kaseda
# Processing Record 4 of Set 8 | saleilua
# City not found. Skipping...
# Processing Record 5 of Set 8 | miguel pereira
# Processing Record 6 of Set 8 | vanavara
# Processing Record 7 of Set 8 | saint anthony
# Processing Record 8 of Set 8 | fort nelson
# Processing Record 9 of Set 8 | gamba
# Processing Record 10 of Set 8 | karlstad
# Processing Record 11 of Set 8 | ust-koksa
# Processing Record 12 of Set 8 | vilcun
# Processing Record 13 of Set 8 | nizhniy tsasuchey
# Processing Record 14 of Set 8 | nautla
# Processing Record 15 of Set 8 | greve strand
# Processing Record 16 of Set 8 | belmonte
# Processing Record 17 of Set 8 | palu
# Processing Record 18 of Set 8 | smolenka
# Processing Record 19 of Set 8 | walker
# Processing Record 20 of Set 8 | lazaro cardenas
# Processing Record 21 of Set 8 | bengkulu
# Processing Record 22 of Set 8 | byron bay
# Processing Record 23 of Set 8 | kavaratti
# Processing Record 24 of Set 8 | umm kaddadah
# Processing Record 25 of Set 8 | kulhudhuffushi
# Processing Record 26 of Set 8 | gizo
# Processing Record 27 of Set 8 | aklavik
# Processing Record 28 of Set 8 | solnechnyy
# Processing Record 29 of Set 8 | chumphon
# Processing Record 30 of Set 8 | hobyo
# Processing Record 31 of Set 8 | rapina
# Processing Record 32 of Set 8 | loa janan
# Processing Record 33 of Set 8 | chimbote
# Processing Record 34 of Set 8 | pangnirtung
# Processing Record 35 of Set 8 | gadung
# Processing Record 36 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 38 of Set 8 | yenagoa
# Processing Record 39 of Set 8 | mitsamiouli
# Processing Record 40 of Set 8 | raga
# Processing Record 41 of Set 8 | erenhot
# Processing Record 42 of Set 8 | college
# Processing Record 43 of Set 8 | husavik
# Processing Record 44 of Set 8 | port moresby
# Processing Record 45 of Set 8 | kaiyuan
# Processing Record 46 of Set 8 | cherskiy
# Processing Record 47 of Set 8 | muli
# Processing Record 48 of Set 8 | ganzhou
# Processing Record 49 of Set 8 | mnogovershinnyy
# Processing Record 50 of Set 8 | cam ranh
# Processing Record 1 of Set 9 | kailua
# Processing Record 2 of Set 9 | maumere
# Processing Record 3 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 4 of Set 9 | yerbogachen
# Processing Record 5 of Set 9 | codrington
# Processing Record 6 of Set 9 | lata
# Processing Record 7 of Set 9 | saldanha
# Processing Record 8 of Set 9 | necochea
# Processing Record 9 of Set 9 | agucadoura
# Processing Record 10 of Set 9 | antofagasta
# Processing Record 11 of Set 9 | jalu
# Processing Record 12 of Set 9 | cidreira
# Processing Record 13 of Set 9 | calama
# Processing Record 14 of Set 9 | luderitz
# Processing Record 15 of Set 9 | luanda
# Processing Record 16 of Set 9 | devonport
# Processing Record 17 of Set 9 | latung
# Processing Record 18 of Set 9 | lompoc
# Processing Record 19 of Set 9 | viedma
# Processing Record 20 of Set 9 | ponta delgada
# Processing Record 21 of Set 9 | xingcheng
# Processing Record 22 of Set 9 | preobrazheniye
# Processing Record 23 of Set 9 | korcula
# Processing Record 24 of Set 9 | bend
# Processing Record 25 of Set 9 | raudeberg
# Processing Record 26 of Set 9 | araxa
# Processing Record 27 of Set 9 | strezhevoy
# Processing Record 28 of Set 9 | silver city
# Processing Record 29 of Set 9 | olafsvik
# Processing Record 30 of Set 9 | hambantota
# Processing Record 31 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 32 of Set 9 | kulachi
# Processing Record 33 of Set 9 | balkanabat
# Processing Record 34 of Set 9 | china
# Processing Record 35 of Set 9 | santa fe
# Processing Record 36 of Set 9 | songea
# Processing Record 37 of Set 9 | shakhtinsk
# Processing Record 38 of Set 9 | salalah
# Processing Record 39 of Set 9 | makakilo city
# Processing Record 40 of Set 9 | acarau
# Processing Record 41 of Set 9 | dongkan
# Processing Record 42 of Set 9 | aguimes
# Processing Record 43 of Set 9 | khorixas
# Processing Record 44 of Set 9 | oyama
# Processing Record 45 of Set 9 | nouakchott
# Processing Record 46 of Set 9 | tezu
# Processing Record 47 of Set 9 | atar
# Processing Record 48 of Set 9 | vao
# Processing Record 49 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 50 of Set 9 | luwuk
# Processing Record 1 of Set 10 | kiunga
# Processing Record 2 of Set 10 | corrente
# Processing Record 3 of Set 10 | owensboro
# Processing Record 4 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 5 of Set 10 | saint-pierre
# Processing Record 6 of Set 10 | nuuk
# Processing Record 7 of Set 10 | angoche
# Processing Record 8 of Set 10 | alofi
# Processing Record 9 of Set 10 | leh
# Processing Record 10 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 10 | grand-santi
# Processing Record 13 of Set 10 | nampa
# Processing Record 14 of Set 10 | neyshabur
# Processing Record 15 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 10 | conde
# Processing Record 17 of Set 10 | caucaia
# Processing Record 18 of Set 10 | cedar city
# Processing Record 19 of Set 10 | baihar
# Processing Record 20 of Set 10 | vuktyl
# Processing Record 21 of Set 10 | flin flon
# Processing Record 22 of Set 10 | araceli
# Processing Record 23 of Set 10 | galle
# Processing Record 24 of Set 10 | alyangula
# Processing Record 25 of Set 10 | chapais
# Processing Record 26 of Set 10 | forestville
# Processing Record 27 of Set 10 | providencia
# Processing Record 28 of Set 10 | cervo
# Processing Record 29 of Set 10 | ohangaron
# Processing Record 30 of Set 10 | okhotsk
# Processing Record 31 of Set 10 | matamoros
# Processing Record 32 of Set 10 | salisbury
# Processing Record 33 of Set 10 | tiksi
# Processing Record 34 of Set 10 | srandakan
# Processing Record 35 of Set 10 | harbour breton
# Processing Record 36 of Set 10 | ndele
# Processing Record 37 of Set 10 | zimapan
# Processing Record 38 of Set 10 | fortuna
# Processing Record 39 of Set 10 | straldza
# City not found. Skipping...
# Processing Record 40 of Set 10 | yulara
# Processing Record 41 of Set 10 | port hedland
# Processing Record 42 of Set 10 | honiara
# Processing Record 43 of Set 10 | taltal
# Processing Record 44 of Set 10 | marrakesh
# Processing Record 45 of Set 10 | roros
# Processing Record 46 of Set 10 | hofn
# Processing Record 47 of Set 10 | manono
# Processing Record 48 of Set 10 | kushiro
# Processing Record 49 of Set 10 | vila
# Processing Record 50 of Set 10 | clarence town
# Processing Record 1 of Set 11 | udachnyy
# Processing Record 2 of Set 11 | cayenne
# Processing Record 3 of Set 11 | havoysund
# Processing Record 4 of Set 11 | constitucion
# Processing Record 5 of Set 11 | hatta
# Processing Record 6 of Set 11 | impfondo
# Processing Record 7 of Set 11 | slave lake
# Processing Record 8 of Set 11 | juneau
# Processing Record 9 of Set 11 | huron
# Processing Record 10 of Set 11 | nyimba
# Processing Record 11 of Set 11 | selenginsk
# Processing Record 12 of Set 11 | meulaboh
# Processing Record 13 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 14 of Set 11 | jeremie
# Processing Record 15 of Set 11 | tanshui
# City not found. Skipping...
# Processing Record 16 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 17 of Set 11 | kruisfontein
# Processing Record 18 of Set 11 | ostrovnoy
# Processing Record 19 of Set 11 | castanheira de pera
# Processing Record 20 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 21 of Set 11 | christchurch
# Processing Record 22 of Set 11 | tir pol
# City not found. Skipping...
# Processing Record 23 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 11 | dwarka
# Processing Record 25 of Set 11 | carbonia
# Processing Record 26 of Set 11 | mareeba
# Processing Record 27 of Set 11 | oistins
# Processing Record 28 of Set 11 | saint-francois
# Processing Record 29 of Set 11 | kavieng
# Processing Record 30 of Set 11 | mahaicony
# City not found. Skipping...
# Processing Record 31 of Set 11 | san patricio
# Processing Record 32 of Set 11 | amarillo
# Processing Record 33 of Set 11 | tiznit
# Processing Record 34 of Set 11 | lakhdenpokhya
# Processing Record 35 of Set 11 | camopi
# Processing Record 36 of Set 11 | banda aceh
# Processing Record 37 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 11 | baghdad
# Processing Record 39 of Set 11 | tomatlan
# Processing Record 40 of Set 11 | porterville
# Processing Record 41 of Set 11 | ranong
# Processing Record 42 of Set 11 | asau
# Processing Record 43 of Set 11 | whitehorse
# Processing Record 44 of Set 11 | krasnorechenskiy
# Processing Record 45 of Set 11 | guerrero negro
# Processing Record 46 of Set 11 | denpasar
# Processing Record 47 of Set 11 | palkonda
# Processing Record 48 of Set 11 | ngunguru
# Processing Record 49 of Set 11 | imeni poliny osipenko
# Processing Record 50 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 12 | chermoz
# Processing Record 2 of Set 12 | janakkala
# Processing Record 3 of Set 12 | polur
# Processing Record 4 of Set 12 | mabaruma
# Processing Record 5 of Set 12 | cuautepec
# Processing Record 6 of Set 12 | khorramshahr
# Processing Record 7 of Set 12 | bichis
# Processing Record 8 of Set 12 | san vicente
# Processing Record 9 of Set 12 | kirovskiy
# Processing Record 10 of Set 12 | baracoa
# Processing Record 11 of Set 12 | kandrian
# Processing Record 12 of Set 12 | khandbari
# Processing Record 13 of Set 12 | marzuq
# Processing Record 14 of Set 12 | krutikha
# Processing Record 15 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 12 | tokat
# Processing Record 17 of Set 12 | ugoofaaru
# Processing Record 18 of Set 12 | saint george
# Processing Record 19 of Set 12 | sisophon
# Processing Record 20 of Set 12 | inirida
# Processing Record 21 of Set 12 | birjand
# Processing Record 22 of Set 12 | bonavista
# Processing Record 23 of Set 12 | bull savanna
# Processing Record 24 of Set 12 | paamiut
# Processing Record 25 of Set 12 | nishihara
# Processing Record 26 of Set 12 | ust-maya
# Processing Record 27 of Set 12 | januaria
# Processing Record 28 of Set 12 | mumford
# Processing Record 29 of Set 12 | jennings
# Processing Record 30 of Set 12 | ensenada
# Processing Record 31 of Set 12 | khani
# Processing Record 32 of Set 12 | requena
# Processing Record 33 of Set 12 | aketi
# Processing Record 34 of Set 12 | labuhan
# Processing Record 35 of Set 12 | porbandar
# Processing Record 36 of Set 12 | francavilla al mare
# Processing Record 37 of Set 12 | loudi
# Processing Record 38 of Set 12 | urengoy
# Processing Record 39 of Set 12 | talagang
# Processing Record 40 of Set 12 | yichang
# Processing Record 41 of Set 12 | maralal
# Processing Record 42 of Set 12 | zhongshu
# Processing Record 43 of Set 12 | taoudenni
# Processing Record 44 of Set 12 | pahrump
# Processing Record 45 of Set 12 | idrinskoye
# Processing Record 46 of Set 12 | khor
# Processing Record 47 of Set 12 | dunedin
# Processing Record 48 of Set 12 | ferrol
# Processing Record 49 of Set 12 | missoula
# Processing Record 50 of Set 12 | selcuk
# Processing Record 1 of Set 13 | bahia honda
# Processing Record 2 of Set 13 | vanderhoof
# Processing Record 3 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 13 | praia da vitoria
# Processing Record 5 of Set 13 | cizre
# Processing Record 6 of Set 13 | portmore
# Processing Record 7 of Set 13 | shchelkun
# Processing Record 8 of Set 13 | arys
# Processing Record 9 of Set 13 | batman
# Processing Record 10 of Set 13 | guna
# Processing Record 11 of Set 13 | filingue
# Processing Record 12 of Set 13 | corpus christi
# Processing Record 13 of Set 13 | coihaique
# Processing Record 14 of Set 13 | bodo
# Processing Record 15 of Set 13 | marsh harbour
# Processing Record 16 of Set 13 | kindersley
# Processing Record 17 of Set 13 | namibe
# Processing Record 18 of Set 13 | umm ruwabah
# City not found. Skipping...
# Processing Record 19 of Set 13 | mago
# Processing Record 20 of Set 13 | yaransk
# Processing Record 21 of Set 13 | hohhot
# Processing Record 22 of Set 13 | komsomolskiy
# Processing Record 23 of Set 13 | joshimath
# Processing Record 24 of Set 13 | houston
# Processing Record 25 of Set 13 | barra patuca
# Processing Record 26 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 27 of Set 13 | gawler
# Processing Record 28 of Set 13 | mungwi
# Processing Record 29 of Set 13 | pecos
# Processing Record 30 of Set 13 | muravlenko
# Processing Record 31 of Set 13 | karasjok
# Processing Record 32 of Set 13 | port blair
# Processing Record 33 of Set 13 | san andres
# Processing Record 34 of Set 13 | dmytrivka
# Processing Record 35 of Set 13 | okmulgee
# Processing Record 36 of Set 13 | vostok
# Processing Record 37 of Set 13 | xinmin
# Processing Record 38 of Set 13 | klaksvik
# Processing Record 39 of Set 13 | mae sai
# Processing Record 40 of Set 13 | guiglo
# Processing Record 41 of Set 13 | mecca
# Processing Record 42 of Set 13 | gimli
# Processing Record 43 of Set 13 | korla
# Processing Record 44 of Set 13 | leibnitz
# Processing Record 45 of Set 13 | katherine
# Processing Record 46 of Set 13 | williston
# Processing Record 47 of Set 13 | porto belo
# Processing Record 48 of Set 13 | lodwar
# Processing Record 49 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 50 of Set 13 | roudnice
# Processing Record 1 of Set 14 | tucuma
# Processing Record 2 of Set 14 | moussoro
# Processing Record 3 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 14 | monschau
# Processing Record 5 of Set 14 | atambua
# Processing Record 6 of Set 14 | marystown
# Processing Record 7 of Set 14 | macau
# Processing Record 8 of Set 14 | domoni
# Processing Record 9 of Set 14 | cristobal obregon
# Processing Record 10 of Set 14 | tarhunah
# City not found. Skipping...
# Processing Record 11 of Set 14 | bell ville
# Processing Record 12 of Set 14 | porto seguro
# Processing Record 13 of Set 14 | deputatskiy
# Processing Record 14 of Set 14 | hami
# Processing Record 15 of Set 14 | shunyi
# Processing Record 16 of Set 14 | verkh-usugli
# Processing Record 17 of Set 14 | mayor pablo lagerenza
# Processing Record 18 of Set 14 | ayautla
# City not found. Skipping...
# Processing Record 19 of Set 14 | ati
# Processing Record 20 of Set 14 | nanfeng
# Processing Record 21 of Set 14 | tres lagoas
# Processing Record 22 of Set 14 | skibbereen
# Processing Record 23 of Set 14 | morant bay
# Processing Record 24 of Set 14 | berlevag
# Processing Record 25 of Set 14 | peruibe
# Processing Record 26 of Set 14 | gerash
# Processing Record 27 of Set 14 | gat
# Processing Record 28 of Set 14 | dong xoai
# Processing Record 29 of Set 14 | vallenar
# Processing Record 30 of Set 14 | arman
# Processing Record 31 of Set 14 | itacare
# Processing Record 32 of Set 14 | manaus
# Processing Record 33 of Set 14 | ekhabi
# Processing Record 34 of Set 14 | teya
# Processing Record 35 of Set 14 | gigmoto
# Processing Record 36 of Set 14 | ayr
# Processing Record 37 of Set 14 | puerto madryn
# Processing Record 38 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 39 of Set 14 | evensk
# Processing Record 40 of Set 14 | kula
# Processing Record 41 of Set 14 | abbeville
# Processing Record 42 of Set 14 | laguna
# Processing Record 43 of Set 14 | staraya poltavka
# Processing Record 44 of Set 14 | muttupet
# Processing Record 45 of Set 14 | qasigiannguit
# Processing Record 46 of Set 14 | malpe
# Processing Record 47 of Set 14 | santo tomas
# Processing Record 48 of Set 14 | kodinsk
# Processing Record 49 of Set 14 | verkhoyansk
# Processing Record 50 of Set 14 | lochristi
# Processing Record 1 of Set 15 | malaya vishera
# Processing Record 2 of Set 15 | isla vista
# Processing Record 3 of Set 15 | waingapu
# Processing Record 4 of Set 15 | tome-acu
# City not found. Skipping...
# Processing Record 5 of Set 15 | dauphin
# Processing Record 6 of Set 15 | olinda
# Processing Record 7 of Set 15 | suhindol
# Processing Record 8 of Set 15 | kirakira
# Processing Record 9 of Set 15 | dom pedrito
# Processing Record 10 of Set 15 | benguela
# Processing Record 11 of Set 15 | grants
# Processing Record 12 of Set 15 | hvide sande
# Processing Record 13 of Set 15 | jaguarao
# Processing Record 14 of Set 15 | gazli
# Processing Record 15 of Set 15 | jerome
# Processing Record 16 of Set 15 | anadyr
# Processing Record 17 of Set 15 | aras
# Processing Record 18 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 19 of Set 15 | barra do garcas
# Processing Record 20 of Set 15 | svolvaer
# Processing Record 21 of Set 15 | la orilla
# Processing Record 22 of Set 15 | derzhavinsk
# Processing Record 23 of Set 15 | belaya gora
# Processing Record 24 of Set 15 | betioky
# Processing Record 25 of Set 15 | santa barbara
# Processing Record 26 of Set 15 | orocue
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 656

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Nenjiang  49.1833  125.2167     36.12        97         100       16.82
# 1     Zyryanka  65.7500  150.8500     11.21        93          92       10.76
# 2    Omsukchan  62.5333  155.8000     20.61        94         100       10.20
# 3      Rikitea -23.1203 -134.9692     76.78        74          73       14.85
# 4  Tuktoyaktuk  69.4541 -133.0374     32.95        95         100        5.93
# 5     Arrecife  28.9630  -13.5477     67.98        73          20        5.75
# 6        Bluff -46.6000  168.3333     51.80        67          98       24.14
# 7       Hobart -42.8794  147.3294     49.26        94          20        5.75
# 8     Caraquet  47.7941  -64.9386     43.14        80         100        5.64
# 9       Akdepe  42.0551   59.3788     62.44        45         100       13.62
#
#   Country                 Date Current Description
# 0      CN  2022-04-25 21:15:13     overcast clouds
# 1      RU  2022-04-25 21:15:13     overcast clouds
# 2      RU  2022-04-25 21:15:14                snow
# 3      PF  2022-04-25 21:15:14          light rain
# 4      CA  2022-04-25 21:05:36     overcast clouds
# 5      ES  2022-04-25 21:15:15          few clouds
# 6      NZ  2022-04-25 21:15:15     overcast clouds
# 7      AU  2022-04-25 21:14:42                 fog
# 8      CA  2022-04-25 21:13:02     overcast clouds
# 9      TM  2022-04-25 21:15:16     overcast clouds

# %%
# Reorder Rows
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", 
                    "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0     Nenjiang      CN  2022-04-25 21:15:13  49.1833  125.2167     36.12
# 1     Zyryanka      RU  2022-04-25 21:15:13  65.7500  150.8500     11.21
# 2    Omsukchan      RU  2022-04-25 21:15:14  62.5333  155.8000     20.61
# 3      Rikitea      PF  2022-04-25 21:15:14 -23.1203 -134.9692     76.78
# 4  Tuktoyaktuk      CA  2022-04-25 21:05:36  69.4541 -133.0374     32.95
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        97         100       16.82     overcast clouds
# 1        93          92       10.76     overcast clouds
# 2        94         100       10.20                snow
# 3        74          73       14.85          light rain
# 4        95         100        5.93     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
